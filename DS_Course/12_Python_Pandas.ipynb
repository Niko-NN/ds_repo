# %% [markdown]
# # 1. Введение

# %%
import pandas as pd

melb_df = pd.read_csv('/content/sample_data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
# Задание 1.1
# Преобразуйте столбец Date в формат datetime и выделите квартал (quarter) продажи объектов недвижимости. 
# Найдите второй по популярности квартал продажи. 
# В качестве ответа запишите число объектов, проданных в этом квартале.
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
quarter_mask = melb_df['Date'].dt.quarter.mode()[0]
quarter_mask2 = melb_df[melb_df['Date'].dt.quarter != quarter_mask]['Date'].dt.quarter.mode()[0]
melb_df[melb_df['Date'].dt.quarter == quarter_mask2].shape[0]
# Out:
# 4359

# %%
# Задание 1.2
# Преобразуйте все столбцы, в которых меньше 150 уникальных значений, 
# в тип данных category, 
# исключив из преобразования столбцы Date, Rooms, Bedroom, Bathroom, Car.
# В качестве ответа запишите результирующее количество столбцов, 
# которые имеют тип данных category.

# список столбцов, которые мы не берём во внимание
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
# задаём максимальное число уникальных категорий
max_unique_count = 150
# цикл по именам столбцов
for col in melb_df.columns:
    # проверяем условие
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude:
        # преобразуем тип столбца
        melb_df[col] = melb_df[col].astype('category')
# выводим её на экран
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %% [markdown]
# ---
#
# # 2. Сортировка данных в DataFrame

# %% [markdown]
# МЕТОД SORT_VALUES()

# %% [markdown]
# СОРТИРОВКА ПО ЗНАЧЕНИЯМ ОДНОГО СТОЛБЦА

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %% [markdown]
# СОРТИРОВКА ПО ЗНАЧЕНИЯМ НЕСКОЛЬКИХ СТОЛБЦОВ

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 2652        6.4    85000.0
# 7116        7.8   200000.0
# 5206       11.2   220000.0
# 7240        8.2   241000.0
# 2898       13.0   250000.0
# ...         ...        ...
# 13341       6.3  4060000.0
# 8591        1.5  4275000.0
# 1094       11.2  4700000.0
# 5801        6.1  5046000.0
# 251         6.3  5525000.0
#
# [1358 rows x 2 columns]

# %%
# Предположим, 
# компания McGrath поручила нам восстановить хронологию продаж таунхаусов, 
# у которых площадь участка существенно больше площади здания, чтобы понять, 
# как часто компания справляется с таким сложным видом объектов. 
# Объекты, проданные в один и тот же день, 
# мы бы хотели сортировать по значению коэффициента соотношения площадей. 

mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %% [markdown]
# ---

# %%
# Задание 2.2
# Произведите сортировку столбца AreaRatio по убыванию. 
# При этом индексы полученной таблицы замените на новые. 
# Какое значение площади здания находится в строке 1558? 
# Ответ округлите до целого числа.

melb_df.sort_values(
    by=['AreaRatio'],
    ascending=[False],
    ignore_index=True
).loc[1558, ['BuildingArea']]
# Out:
# BuildingArea    126.0
# Name: 1558, dtype: object

# %%
# Задание 2.3
# Найдите таунхаусы (Type) с количеством жилых комнат (Rooms) больше 2. 
# Отсортируйте полученную таблицу сначала по возрастанию числа комнат, 
# а затем по убыванию средней площади комнат (MeanRoomsSquare). 
# Индексы таблицы замените на новые. 
# Какая цена будет у объекта в строке 18? 
# Ответ запишите в виде целого числа.

mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
melb_df[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, ['Price']]
# Out:
# Price    1300000.0
# Name: 18, dtype: object

# %% [markdown]
# ---
#
# # 3. Группировка данных в DataFrame

# %% [markdown]
# МЕТОД GROUPBY()

# %% [markdown]
# ГРУППИРОВКА ДАННЫХ ПО ОДНОМУ КРИТЕРИЮ С ОДНОЙ АГРЕГАЦИЕЙ

# %%
melb_df.groupby(by='Type').mean()
# Out:
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
#            Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# Type
# house        7259.025505        18.996731  -0.490031    55.669700
# townhouse    7094.459605        18.569847  -0.094916    26.690305
# unit         8199.280080        21.068242   0.319883    39.703016

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %% [markdown]
# ГРУППИРОВКА ДАННЫХ ПО ОДНОМУ КРИТЕРИЮ С НЕСКОЛЬКИМИ АГРЕГАЦИЯМИ

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Gary, hockingstuart, Jellis, Buxton, Woodards...
# Eastern Victoria            {Fletchers, hockingstuart, Ray, C21, McGrath, ...
# Northern Metropolitan       {hockingstuart, Jellis, Hodges, Alexkarbon, Bu...
# Northern Victoria           {YPA, hockingstuart, Raine, McDonald, McGrath,...
# South-Eastern Metropolitan  {Gary, hockingstuart, Jellis, Buxton, Hodges, ...
# Southern Metropolitan       {Gary, hockingstuart, Williams, Jellis, Buxton...
# ...

# %% [markdown]
# ---

# %%
# Задание 3.1
# Сгруппируйте данные по признаку количества комнат 
# и найдите среднюю цену объектов недвижимости в каждой группе. 
# В качестве ответа запишите количество комнат, 
# для которых средняя цена наибольшая.
melb_df.groupby('Rooms')['Price'].agg('mean').sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
# Задание 3.2
# Какой регион имеет наименьшее стандартное отклонение по географической широте (Lattitude)?
# В качестве ответа запишите название этого региона.
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Out:
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
# Задание 3.3
# Какая риелторская компания (SellerG) имеет наименьшую общую выручку 
# за период с 1 мая по 1 сентября (включительно) 2017 года?
# Для ответа на этот вопрос рассчитайте сумму продаж (Price) каждой компании в заданный период.
# Не забудьте перевести даты в формат datetime.
melb_df[(melb_df['Date'] >= '2017-05-01') & (melb_df['Date'] < '2017-09-02')].groupby('SellerG')['Price'].sum().sort_values()
# Out:
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# Purplebricks      23401000.0
# O'Brien           23855508.0
# HAR               25568000.0
# Village           26473000.0
# RW                29261000.0
# Raine             30687700.0
# Stockdale         35409800.0
# Sweeney           36882750.0
# Gary              39138400.0
# Hodges            43231000.0
# YPA               46354350.0
# Miles             47582000.0
# ...

# %% [markdown]
# ---
#
# # 4. Сводные таблицы

# %% [markdown]
# МЕТОД GROUPBY КАК СПОСОБ ПОСТРОЕНИЯ СВОДНЫХ ТАБЛИЦ

# %%
melb_df.groupby('Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
#        unit         5.200000e+05
# 7      house        1.920700e+06
#        townhouse             NaN
#        unit                  NaN
# 8      house        1.510286e+06
#        townhouse             NaN
#        unit         2.250000e+06
# 10     house        9.000000e+05
#        townhouse             NaN
#        unit                  NaN
# Name: Price, dtype: float64

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %% [markdown]
# МЕТОД PIVOT_TABLE ДЛЯ ПОСТРОЕНИЯ СВОДНЫХ ТАБЛИЦ

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %% [markdown]
# МНОГОМЕРНЫЕ СВОДНЫЕ ТАБЛИЦЫ

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %% [markdown]
# ДОСТУП К ДАННЫМ В СВОДНОЙ ТАБЛИЦЕ

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

# %%
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                       mean              \
# Type                   house townhouse unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0    0  569.643881  278.858824
# Western Metropolitan   531.0     198.0   62  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
print(list(filtered_pivot.index))
# ['Southern Metropolitan', 'Western Metropolitan']
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
import numpy as np
mser = pd.Series(
    np.random.rand(8),
	index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
# Out:
# white  up       0.733983
#        down     0.149648
#        right    0.452538
# blue   up       0.553280
#        down     0.168366
# red    up       0.209946
#        down     0.599901
#        left     0.451919
# dtype: float64

# %%
print(mser.index)
# Out:
# MultiIndex([('white',    'up'),
#             ('white',  'down'),
#             ('white', 'right'),
#             ( 'blue',    'up'),
#             ( 'blue',  'down'),
#             (  'red',    'up'),
#             (  'red',  'down'),
#             (  'red',  'left')],
#            )

# %%
mframe = pd.DataFrame(
    np.random.randn(16).reshape(4,4),
    index=[['white','white','red','red'], ['up','down','up','down']],
    columns=[['pen','pen','paper','paper'],[1,2,1,2]]
)
display(mframe)
# Out:
#                  pen               paper
#                    1         2         1         2
# white up    0.686025 -1.060897  1.089210 -0.888481
#       down -2.018207  0.214196  0.724434  0.699777
# red   up   -0.653314  0.670900 -1.314368  0.712781
#       down -1.081509 -0.508422  0.836509 -0.749925

# %% [markdown]
# ---

# %%
# Задание 4.2
# Составьте сводную таблицу, которая показывает зависимость медианной площади (BuildingArea) 
# здания от типа объекта недвижимости (Type) и количества жилых комнат в доме (Rooms). 
# Для какой комбинации признаков площадь здания наибольшая?
# В качестве ответа запишите эту комбинацию (тип здания, число комнат) через запятую, без пробелов.

melb_df.pivot_table(
    values='BuildingArea',
    index=['Type'],
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
# Out:
# Rooms         1    2    3      4    5    6      7    8    10
# Type
# house      126.0  126  126  141.0  177  126  216.5  126  126
# townhouse   88.0  114  126  159.5  152    0    0.0    0    0
# unit        69.5  110  126  126.0    0  171    0.0  126    0

# %%
# Задание 4.3
# Составьте сводную таблицу, 
# которая показывает зависимость медианной цены объекта недвижимости (Price) 
# от риелторского агентства (SellerG) и типа здания (Type).
# Во вновь созданной таблице найдите агентство, 
# у которого медианная цена для зданий типа unit максимальна. 
# В качестве ответа запишите название этого агентства.
sllrg_tp_prc_mdn = melb_df.pivot_table(
    values='Price',
    index=['SellerG'],
    columns='Type',
    aggfunc='median',
    fill_value=0
)

# %%
sllrg_tp_prc_mdn['unit'].sort_values(ascending=False)
# Out:
# SellerG
# Nick             900000
# Marshall         715000
# Cayzer           707500
# Kay              695000
# Noel             693250
# Buxton           670000
# Fletchers        653000
# Chisholm         640000
# Philip           636000
# RT               630000
# C21              625500
# RW               625500
# Moonee           622000
# O'Brien          618500
# Hodges           605500
# Eview            602000
# Woodards         600000
# Collins          592000
# Jellis           591750
# Purplebricks     582500
# Williams         577000
# hockingstuart    566000
# Alexkarbon       560000
# Miles            555000
# Buckingham       553000
# Gary             550000
# Biggin           548000
# Greg             547500
# McGrath          542500
# other            535000
# Nelson           530000
# HAR              518000
# McDonald         502500
# Barry            502000
# Harcourts        500000
# Ray              497500
# Thomson          495000
# Douglas          494500
# ...

# %% [markdown]
# ---
#
# # 5. Объединение DataFrame: знакомимся с новыми данными

# %% [markdown]
# С КАКИМИ ДАННЫМИ МЫ РАБОТАЕМ?

# %%
ratings1 = pd.read_csv('/content/sample_data/ratings1.csv')
ratings1
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 39996     274     5582     2.5
# 39997     274     5585     3.5
# 39998     274     5588     3.5
# 39999     274     5618     4.0
# 40000     274     5621     2.0
#
# [40001 rows x 3 columns]

# %%
ratings2 = pd.read_csv('/content/sample_data/ratings2.csv')
ratings2
# Out:
#        userId  movieId  rating
# 0         274     5621     2.0
# 1         274     5630     3.0
# 2         274     5667     3.5
# 3         274     5679     3.5
# 4         274     5690     3.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [60836 rows x 3 columns]

# %%
# Задание 5.2
# Сколько уникальных фильмов представлено в таблице movies?
movies = pd.read_csv('/content/sample_data/movies.csv')
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
# Задание 5.3
# Сколько уникальных пользователей в таблице ratings1?
ratings1['userId'].nunique()
# Out:
# 274

# %%
# Задание 5.4
# В каком году было выставлено больше всего оценок?
# Для ответа на этот вопрос используйте таблицу dates.
dates = pd.read_csv('/content/sample_data/dates.csv')
dates['date'] = pd.to_datetime(dates['date'])
dates['date'].dt.year.mode()
# Out:
# 0    2000
# dtype: int64

# %% [markdown]
# ---
#
# # 6. Объединение DataFrame: concat

# %%
ratings = pd.concat([ratings1, ratings2])
display(ratings)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
ratings = pd.concat(
    [ratings1, ratings2],
    ignore_index=True
)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Число строк в таблице ratings: 100837
# Число строк в таблице dates: 100836
# False
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
display(ratings1.tail(1))
display(ratings2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Число строк в таблице ratings: 100836
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %% [markdown]
# ---

# %%
# ЗАДАНИЕ 6.3
# Допустим, в ваше распоряжение предоставлена директория "./Root/users/". 
# В данной директории содержатся csv-файлы, 
# в каждом из которых хранится информация об идентификаторах пользователей (user_id) 
# и ссылки на их фотографии (photo_url). 

# Каждый файл из папки users имеет примерно следующую структуру:
# При проверке в директории может быть сколько угодно файлов 
# (директория может изменяться в зависимости от устройства файловой системы).

# Вам необходимо написать функцию concat_user_files(path), 
# параметром которой является path — путь до директории. 
# Функция должна объединить информацию из предоставленных вам файлов в один DataFrame и вернуть его. 

# Список названий всех файлов, находящихся в директории, 
# вы можете получить с помощью функции os.listdir(path) из модуля os 
# (модуль уже импортирован в файле main.py). 
# Например, для директории "./Root/users/" результатом работы функции будет список:

# Примечание. 
# Модуль os позволяет работать с операционной системой компьютера прямо из кода.

# Отсортируйте этот список, прежде чем производить объединение файлов.

# Когда вы получите отсортированный список, 
# вам останется только прочитать все csv-файлы из списка в цикле 
# и объединить прочитанные таблицы между собой.

# Однако обратите внимание, 
# что метод os.listdir() возвращает только список имён файлов в указанной директории, 
# а при чтении файла необходимо указывать полный путь до него. 
# То есть путь для чтения будет таким:

# './Root/users/{file_name}'
# Не забудьте обновить индексы результирующей таблицы после объединения.

# Учтите, что на тестовом наборе файлов в результате объединения могут возникнуть дубликаты, 
# от которых необходимо будет избавиться.

# %%
# import os
# def concat_users_files(path):
#     data = pd.DataFrame()
#     file_names = os.listdir(path)
#     file_names.sort()
#     for file in file_names:
#         tmp_data = pd.read_csv(path + file)
#         data = pd.concat([data, tmp_data], ignore_index=True)
#     data = data.drop_duplicates()
#     return data

# %% [markdown]
# ---
#
# # 7. Объединение DataFrame: join, merge

# %% [markdown]
# ТИПЫ ОБЪЕДИНЕНИЙ

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %% [markdown]
# МЕТОД ОБЪЕДИНЕНИЯ MERGE

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Число строк в таблице ratings_dates: 100836
# Число строк в таблице merged: 100836
# True
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %% [markdown]
# ОСОБЕННОСТИ ИСПОЛЬЗОВАНИЯ MERGE()

# %%
merged2 = ratings_dates.merge(
    movies,
    on='movieId',
    how='outer'
)
print('Число строк в таблице merged2: ', merged2.shape[0])
display(merged2.tail())
# Число строк в таблице merged: 100854
# Out:
# Число строк в таблице merged2:  100854
#         userId  movieId  rating date                               title  \
# 100849     NaN    30892     NaN  NaT  In the Realms of the Unreal (2004)
# 100850     NaN    32160     NaN  NaT            Twentieth Century (1934)
# 100851     NaN    32371     NaN  NaT           Call Northside 777 (1948)
# 100852     NaN    34482     NaN  NaT        Browning Version, The (1951)
# 100853     NaN    85565     NaN  NaT                  Chalet Girl (2011)
#
#                        genres
# 100849  Animation|Documentary
# 100850                 Comedy
# 100851  Crime|Drama|Film-Noir
# 100852                  Drama
# 100853         Comedy|Romance

# %%
merge_ratings = ratings1.merge(ratings2, how='outer')
print('Число строк в таблице merge_ratings: ', merge_ratings.shape[0])
display(merge_ratings)
# Число строк в таблице merge_ratings: 100836
# Out:
# Число строк в таблице merge_ratings:  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# КАКОЙ МЕТОД ОБЪЕДИНЕНИЯ ИСПОЛЬЗОВАТЬ?

# %% [markdown]
# ---

# %%
# Задание 7.3
data_1 = pd.DataFrame({'Value': [100, 45, 80],
                       'Group': [1, 4, 5]},
                      index = ['I0', 'I1', 'I2']
                     )
data_1
# Out:
#     Value  Group
# I0    100      1
# I1     45      4
# I2     80      5

# %%
data_2 = pd.DataFrame({'Company': ['Google', 'Amazon', 'Facebook'],
                       'Add': ['S0', 'S1', 'S7']},
                      index = ['I0', 'I1', 'I3']
                     )
data_2
# Out:
#      Company Add
# I0    Google  S0
# I1    Amazon  S1
# I3  Facebook  S7

# %%
data_1.join(data_2, how='inner')
# Out:
#     Value  Group Company Add
# I0    100      1  Google  S0
# I1     45      4  Amazon  S1

# %% [markdown]
# ---

# %%
# Задание 7.4
a = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [103, 214, 124], 'C': [1, 4, 2]})
b = pd.DataFrame({'V': ['d', 'b', 'c'], 'U': [1393.7, 9382.2, 1904.5], 'C': [1, 3, 2]})
display(a, b)
# Out:
#    A    B  C
# 0  a  103  1
# 1  b  214  4
# 2  c  124  2
#    V       U  C
# 0  d  1393.7  1
# 1  b  9382.2  3
# 2  c  1904.5  2

# %%
a.merge(b, how='right', on='C')
# Out:
#      A      B  C  V       U
# 0    a  103.0  1  d  1393.7
# 1  NaN    NaN  3  b  9382.2
# 2    c  124.0  2  c  1904.5

# %% [markdown]
# ---

# %%
# ЗАДАНИЕ 7.5
# Даны две таблицы: items_df, 
# в которой содержится информация о наличии товаров на складе, 
# и purchase_df — с данными о покупках товаров.
# Информация в таблицах представлена в виде следующих столбцов:
# item_id — идентификатор модели;
# vendor — производитель модели;
# stock_count — имеющееся на складе количество данных моделей (в штуках);
# purchase_id — идентификатор покупки;
# price — стоимость модели в покупке.
# Сформируйте DataFrame merged, 
# в котором в результате объединения purchase_df и items_df останутся модели, 
# которые учтены на складе и имели продажи.
# Из таблицы merged найдите суммарную выручку, 
# которую можно было бы получить от продажи всех товаров, 
# которые учтены на складе и имели продажи. 
# Результат занесите в переменную income.

items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})

purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})
merged = items_df.merge(purchase_df)
income = (merged['price'] * merged['stock_count']).sum()

# %%
income
# Out:
# 19729490

# %%
merged
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
items_df
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19

# %%
purchase_df
# Out:
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %% [markdown]
# ---
#
# # 8. Закрепление знаний

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
ratings_movies = pd.read_csv('/content/sample_data/ratings_movies.csv')
ratings_movies
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)
ratings_movies.info()

# %%
# Задание 8.1
ratings_movies['year_release'].isna().sum()
# Out:
# 18

# %%
# Задание 8.2
m_1999 = ratings_movies['year_release'] == 1999
ratings_movies[m_1999].groupby('title')['rating'].mean().sort_values()

# %%
# Задание 8.3
m_2010 = ratings_movies['year_release'] == 2010
ratings_movies[m_2010].groupby('genres')['rating'].mean().sort_values()

# %%
# Задание 8.4
ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)

# %%
# Задание 8.5
ratings_movies.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(by=['count', 'mean'], ascending=[True, False])

# %%
# Задание 8.6
m_2018 = ratings_movies['year_release'] == 2018
ratings_movies[m_2018].groupby('genres')['rating'].agg(
    ['count', 'mean']
).sort_values(by=['count', 'mean'], ascending=[False, False])

# %%
# Задание 8.7
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'])
ratings_movies.info()

# %%
ratings_movies['year_rating'] = ratings_movies['date'].dt.year
ratings_movies

# %%
pivot = ratings_movies.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
pivot

# %%
pivot.loc[2018].sort_values(ascending=False).head(20)

# %%
pivot.loc[:,'Comedy']

# %% [markdown]
# ---

# %%
# Дано два файла:

# orders.csv, содержащий данные о заказах;
# products.csv, содержащий данные о товарах.

# %%
orders = pd.read_csv('/content/sample_data/orders.csv', sep = ";")
orders

# %%
products = pd.read_csv('/content/sample_data/products.csv', sep = ";")
products

# %%
orders_products = orders.merge(products, how='left', left_on='ID товара', right_on='Product_ID')
orders_products

# %%
# Задание 8.10
mask = orders_products['Оплачен'] == 'Да'

# %%
orders_products['profit'] = orders_products['Количество'] * orders_products['Price']
orders_products

# %%
orders_products[mask].groupby('ID Покупателя')['profit'].sum().sort_values()
# Out:
# ID Покупателя
# 1        0.0
# 8     1344.0
# 5    13043.0
# 7    17096.0
# Name: profit, dtype: float64
